# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
THC = yf.download("THC", start="2024-01-29")
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_74795/1093075763.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   THC = yf.download("THC", start="2024-01-29")
# [*********************100%***********************]  1 of 1 completed

# %%
thc = THC[['Close']]
thc
# Out:
# Price            Close
# Ticker             THC
# Date
# 2024-01-29   83.570000
# 2024-01-30   82.739998
# 2024-01-31   82.739998
# 2024-02-01   89.110001
# 2024-02-02   89.330002
# ...                ...
# 2025-07-21  174.649994
# 2025-07-22  155.970001
# 2025-07-23  158.309998
# 2025-07-24  148.380005
# 2025-07-25  153.020004
#
# [374 rows x 1 columns]

# %%
thc["EMA20"]=thc["Close"]["THC"].ewm(span=20,min_periods=20).mean()
thc["EMA50"]=thc["Close"]["THC"].ewm(span=50,min_periods=50).mean()
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_74795/440541201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thc["EMA20"]=thc["Close"]["THC"].ewm(span=20,min_periods=20).mean()
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_74795/440541201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thc["EMA50"]=thc["Close"]["THC"].ewm(span=50,min_periods=50).mean()

# %%
thc.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()
