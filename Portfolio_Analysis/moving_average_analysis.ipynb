# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
THC = yf.download("THC", start="2024-01-29")
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/1093075763.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   THC = yf.download("THC", start="2024-01-29")
# [*********************100%***********************]  1 of 1 completed

# %%
thc = THC[['Close']]
thc
# Out:
# Price            Close
# Ticker             THC
# Date
# 2024-01-29   83.570000
# 2024-01-30   82.739998
# 2024-01-31   82.739998
# 2024-02-01   89.110001
# 2024-02-02   89.330002
# ...                ...
# 2025-07-21  174.649994
# 2025-07-22  155.970001
# 2025-07-23  158.309998
# 2025-07-24  148.380005
# 2025-07-25  153.020004
#
# [374 rows x 1 columns]

# %%
thc.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
thc["SMA50"]=thc["Close"]["THC"].rolling(window=50,min_periods=50).mean()
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/773414015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thc["SMA50"]=thc["Close"]["THC"].rolling(window=50,min_periods=50).mean()

# %%
thc.head(52)
# Out:
# Price            Close      SMA50
# Ticker             THC
# Date
# 2024-01-29   83.570000        NaN
# 2024-01-30   82.739998        NaN
# 2024-01-31   82.739998        NaN
# 2024-02-01   89.110001        NaN
# 2024-02-02   89.330002        NaN
# 2024-02-05   90.040001        NaN
# 2024-02-06   88.440002        NaN
# 2024-02-07   88.110001        NaN
# 2024-02-08   89.019997        NaN
# 2024-02-09   88.089996        NaN
# 2024-02-12   90.540001        NaN
# 2024-02-13   88.070000        NaN
# 2024-02-14   87.940002        NaN
# 2024-02-15   89.900002        NaN
# 2024-02-16   90.930000        NaN
# 2024-02-20   91.169998        NaN
# 2024-02-21   91.459999        NaN
# 2024-02-22   92.379997        NaN
# 2024-02-23   92.800003        NaN
# 2024-02-26   91.809998        NaN
# 2024-02-27   90.230003        NaN
# 2024-02-28   89.220001        NaN
# 2024-02-29   93.000000        NaN
# 2024-03-01   94.290001        NaN
# 2024-03-04   93.699997        NaN
# ...

# %%
thc.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
thc["SMA200"]=thc["Close"]["THC"].rolling(window=200,min_periods=200).mean()
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/2914625368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   thc["SMA200"]=thc["Close"]["THC"].rolling(window=200,min_periods=200).mean()

# %%
thc.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
MSFT = yf.download("MSFT", start="2024-01-29")
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/1993446195.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   MSFT = yf.download("MSFT", start="2024-01-29")
# [*********************100%***********************]  1 of 1 completed

# %%
msft = MSFT[['Close']]
msft
# Out:
# Price            Close
# Ticker            MSFT
# Date
# 2024-01-29  405.121368
# 2024-01-30  404.003998
# 2024-01-31  393.117584
# 2024-02-01  399.247986
# 2024-02-02  406.604523
# ...                ...
# 2025-07-21  510.059998
# 2025-07-22  505.269989
# 2025-07-23  505.869995
# 2025-07-24  510.880005
# 2025-07-25  513.710022
#
# [374 rows x 1 columns]

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
msft["SMA50"]=msft["Close"]["MSFT"].rolling(window=50,min_periods=50).mean()
msft["SMA200"]=msft["Close"]["MSFT"].rolling(window=200,min_periods=200).mean()
# Out:
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/2023677134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   msft["SMA50"]=msft["Close"]["MSFT"].rolling(window=50,min_periods=50).mean()
# /var/folders/tm/tf6jjl7538vd6nlxbkfgphkw0000gn/T/ipykernel_73833/2023677134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   msft["SMA200"]=msft["Close"]["MSFT"].rolling(window=200,min_periods=200).mean()

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()
